# %% [markdown]
# <a href="https://colab.research.google.com/github/charaf19/Machine_Learning/blob/main/Processing_Image_data_in_Python_for_Deep_Learning_Applications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Getting an image using web get
# !wget 'https://people.com/thmb/5uLym456xzuJ5MwbPIdTJiyGoSE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():focal(904x0:906x2)/pug-1-0d4c0f988e3d421ca4954917b1450664.jpg'
# Out:
# --2022-12-17 09:15:54--  https://people.com/thmb/5uLym456xzuJ5MwbPIdTJiyGoSE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():focal(904x0:906x2)/pug-1-0d4c0f988e3d421ca4954917b1450664.jpg
# Resolving people.com (people.com)... 151.101.2.137, 151.101.66.137, 151.101.130.137, ...
# Connecting to people.com (people.com)|151.101.2.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107685 (105K) [image/jpeg]
# Saving to: ‘pug-1-0d4c0f988e3d421ca4954917b1450664.jpg’
#
# pug-1-0d4c0f988e3d4 100%[===================>] 105.16K  --.-KB/s    in 0.01s
#
# 2022-12-17 09:15:54 (7.96 MB/s) - ‘pug-1-0d4c0f988e3d421ca4954917b1450664.jpg’ saved [107685/107685]

# %% [markdown]
# **labraries that can be used for image processing** :
#
#
# *   matplotlib.image
# *   Pillow
# *   OpenCV(cv2)

# %%
#Importing the image module
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#Loading an image through matplotlib library 
img = mpimg.imread('/content/dog.jpg')

# %%
#Displaying the imge from the numpy array 
plt.imshow(img)

# %% [markdown]
# # Resizing the iage using the package pillow

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
#Get the new size of the image
img_resized = img.resize((200,200))

# %%
#Displaying the image
plt.imshow(img_resized)

# %%
#Save the resized image 
img_resized.save('dogre.jpg')

# %% [markdown]
# # Convert RGB images to GrayScale images using OpenCV

# %%
import cv2 
#cv2.imshow() is disabled in Colab, because it causes Jupyter sessions to crash
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/dog.jpg')

# %%
grayscale_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(grayscale_img)

# %%
cv2_imshow(grayscale_img)
# Out:
# <PIL.Image.Image image mode=L size=1500x1070 at 0x7FD5D7D7D550>

# %% [markdown]
# saving the grayscal image

# %%
cv2.imwrite('grascale_image.jpg',grayscale_img)
# Out:
# True
